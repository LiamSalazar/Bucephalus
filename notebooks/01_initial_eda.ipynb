# %% [markdown]
# # Bucephalus initial EDA
#
# Notebook ligero. Ejecuta primero los scripts del pipeline.

# %%
from pathlib import Path
import polars as pl

root = Path('..').resolve()
events = pl.read_parquet(root / 'data/processed/events.parquet')
events.group_by('event_type').len().sort('len', descending=True)
